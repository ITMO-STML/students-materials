# %% [markdown]
# ## Запуск проекта двухагентной системы по созданею лекций в GoogleColab

# %% [markdown]
# ### 1 Настройка пути
#
# Подключите google drive следующей командой

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Теперь необходимо убедиться что мы находимся в правильной папке "lecture_rag_refactor" для этого выполняем следующую команду
#
# В строку %cd "your_path" вставляем путь до папки "lecture_rag_refactor"
#
# Затем проверяем командой "!ls", должно вывести содержимое папки, следующие файлы и папки: colab_setup.ipynb, lecture_rag, requirements.txt,	main_refactored.py, resources,  streamlit_app.p

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/lecture_rag_refactor"
# !ls
# Out:
# /content/drive/MyDrive/Colab Notebooks/lecture_rag_refactor
# cloudflared	   lecture_rag	       requirements.txt  streamlit_app.py
# colab_setup.ipynb  main_refactored.py  resources

# %% [markdown]
# ### 2 Установка библиотек
# Теперь скачиваем все необходимые библиотеки для работы из файла requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 26.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.4/795.4 kB 23.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 49.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 64.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 75.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 50.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 27.1 MB/s  0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 103.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 152.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 131.5 MB/s  0:00:00
# ...

# %% [markdown]
# ### 3 Передача параметров подключения к внешнему LLM
#
# Здесь будет вставлен соответствующий API-ключ

# %%
import os

os.environ["API_KEY"] = "PASTE_YOUR_KEY_HERE"
os.environ["BASE_URL"] = "https://foundation-models.api.cloud.ru/v1"

print("API_KEY set:", bool(os.environ.get("API_KEY")))
print("BASE_URL set:", bool(os.environ.get("BASE_URL")))
# Out:
# API_KEY set: True
# BASE_URL set: True

# %% [markdown]
# ### 4 Работа с интерфейсом
#
# Скачиваем библиотеку streamlit

# %%
# !pip install streamlit
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared
# !chmod +x cloudflared

# %% [markdown]
# * Запускает Streamlit внутри Colab,
#
# * Поднимает сервер на порту 8501

# %%
# !streamlit run streamlit_app.py --server.port 8501 --server.address 0.0.0.0 --server.headless true &> /content/streamlit.log &
# !./cloudflared tunnel --url http://localhost:8501
# Out:
# 2026-01-22T16:38:58Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-01-22T16:38:58Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-01-22T16:39:02Z INF +--------------------------------------------------------------------------------------------+
# 2026-01-22T16:39:02Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# ...

# %% [markdown]
# Теперь интерфейс работающей системы доступен по ссылке https://screening-hurricane-chicken-trailer.trycloudflare.com
